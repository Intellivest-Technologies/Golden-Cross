# %% [markdown]
# # Golden Cross Strategy

# %%
import importlib
import strategy_backtest as s 
importlib.reload(s)
# Out:
# <module 'strategy_backtest' from '/Users/ryankemmer/Golden-Cross/strategy_backtest.py'>

# %% [markdown]
# # Test on 2020 COVID Crash

# %%
import datetime

start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 5, 1)

results = s.backtest_strategy(start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 993.4598846435547
# 1000
# OrderedDict([('MMM', 0)])
# OrderedDict([(Timestamp('2020-01-08 13:30:00-0500', tz='America/New_York'), 'Bought for: 180.6999969482422with stoploss: 180.6999969482422'), (Timestamp('2020-01-08 15:30:00-0500', tz='America/New_York'), 'Sold for 180.6300048828125due to stop criteria being met'), (Timestamp('2020-04-09 11:30:00-0400', tz='America/New_York'), 'Bought for: 147.12669372558594with stoploss: 147.12669372558594'), (Timestamp('2020-04-13 09:30:00-0400', tz='America/New_York'), 'Sold for 146.09500122070312due to stop criteria being met')])
# [*********************100%***********************]  1 of 1 completed
# -12.42559814453125
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 993.8842468261719
# 1000
# ...

# %% [markdown]
# # Test on previous year

# %%
import datetime

start = datetime.datetime(2020, 7, 23)
end = datetime.datetime.now()

results = s.backtest_strategy(start, end)
